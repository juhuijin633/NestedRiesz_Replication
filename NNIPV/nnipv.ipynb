# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from nnpiv.rkhs import ApproxRKHSIVCV
from nnpiv.semiparametrics import DML_longterm

# %%
# Toy shapes: Y,D,S,G are (n,1)
Y, D, S, G = [np.random.randn(10000,1) for _ in range(4)]

m1 = ApproxRKHSIVCV(kernel_approx='nystrom', n_components=400,
                    kernel='rbf', gamma=.001, delta_scale='auto',
                    delta_exp=.4, alpha_scales=np.geomspace(1, 10000, 10), cv=10)
m2 = ApproxRKHSIVCV(kernel_approx='nystrom', n_components=400,
                    kernel='rbf', gamma=.001, delta_scale='auto',
                    delta_exp=.4, alpha_scales=np.geomspace(1, 10000, 10), cv=10)

dml = DML_longterm(Y, D, S, G,
                   longterm_model='surrogacy',
                   model1=[m1,m2], sample_G='G=0',
                   n_folds=5, n_rep=1, CHIM=False,
                   prop_score=LogisticRegression(max_iter=2000))
theta, var, ci = dml.dml()
print(theta, var, ci)
# Out:
# /Users/marvinlob/Documents/RA/NestedRiesz/NNIPV/NNPIV/nnpiv/semiparametrics/dml_longterm.py:231: UserWarning: Sequential outcome model fitting requires nn_1 to be a list. Assuming [nn_1, nn_1]
#   warnings.warn("Sequential outcome model fitting requires nn_1 to be a list. Assuming [nn_1, nn_1]", UserWarning)
# /Users/marvinlob/Documents/RA/NestedRiesz/NNIPV/NNPIV/nnpiv/semiparametrics/dml_longterm.py:238: UserWarning: Sequential outcome model fitting requires fitargs1 to be a list. Assuming [fitargs1, fitargs1]
#   warnings.warn("Sequential outcome model fitting requires fitargs1 to be a list. Assuming [fitargs1, fitargs1]", UserWarning)
# Rep: 1
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/marvinlob/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/joblib/_utils.py", line 72, in __call__
#     return self.func(**kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/joblib/parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/joblib/parallel.py", line 607, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/Documents/RA/NestedRiesz/NNIPV/NNPIV/nnpiv/semiparametrics/dml_longterm.py", line 1028, in _process_fold
#     delta_0, nu_1, nu_0 = self._nnpivfit_outcome_surrogacy_s(train_Y, train_D, train_S, train_X, train_G)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/Documents/RA/NestedRiesz/NNIPV/NNPIV/nnpiv/semiparametrics/dml_longterm.py", line 743, in _nnpivfit_outcome_surrogacy_s
#     bridge_1 = model_1.fit(A1, A1, Y1)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/Documents/RA/NestedRiesz/NNIPV/NNPIV/nnpiv/rkhs/rkhsiv.py", line 580, in fit
#     RootKf = self.featZ.fit_transform(Z)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 316, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/sklearn/base.py", line 894, in fit_transform
#     return self.fit(X, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/sklearn/base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/sklearn/kernel_approximation.py", line 1012, in fit
#     X = validate_data(self, X, accept_sparse="csr")
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/sklearn/utils/validation.py", line 2954, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/marvinlob/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/sklearn/utils/validation.py", line 1128, in check_array
#     raise ValueError(
# ValueError: Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required by Nystroem.
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 16
#       7 m2 = ApproxRKHSIVCV(kernel_approx='nystrom', n_components=400,
#       8                     kernel='rbf', gamma=.001, delta_scale='auto',
#       9                     delta_exp=.4, alpha_scales=np.geomspace(1, 10000, 10), cv=10)
#      11 dml = DML_longterm(Y, D, S, G,
#      12                    longterm_model='surrogacy',
#      13                    model1=[m1,m2], sample_G='G=0',
#      14                    n_folds=5, n_rep=1, CHIM=False,
#      15                    prop_score=LogisticRegression(max_iter=2000))
# ---> 16 theta, var, ci = dml.dml()
#      17 print(theta, var, ci)
#
# File ~/Documents/RA/NestedRiesz/NNIPV/NNPIV/nnpiv/semiparametrics/dml_longterm.py:1302, in DML_longterm.dml(self)
#    1293 def dml(self):
#    1294     """
#    1295     Perform Debiased Machine Learning for Nonparametric Instrumental Variables.
#    1296
#    (...)   1300         Estimated values, variances, and confidence intervals.
#    1301     """
# -> 1302     theta, theta_var, confidence_interval, theta_cov_hat = self._split_and_estimate()
#    1303     if self.V is None:
#    1304         return theta[0], theta_var[0], confidence_interval[0]
#
# File ~/Documents/RA/NestedRiesz/NNIPV/NNPIV/nnpiv/semiparametrics/dml_longterm.py:1256, in DML_longterm._split_and_estimate(self)
#    1254 kf = KFold(n_splits=self.n_folds, shuffle=True, random_state=self.random_seed+rep)
#    1255 if self.V is None:
# -> 1256     fold_results = Parallel(n_jobs=-1, backend='threading')(
#    1257         delayed(self._process_fold)(
#    1258             fold_idx,
#    1259             (self.Y[train_index], self.D[train_index], self.S[train_index], self.X[train_index], self.G[train_index]),
#    1260             (self.Y[test_index], self.D[test_index], self.S[test_index], self.X[test_index], self.G[test_index]))
#    1261             for fold_idx, (train_index, test_index) in enumerate(kf.split(self.Y))
#    1262     )
#    1263 else:
#    1264     fold_results = Parallel(n_jobs=-1, backend='threading')(
#    1265         delayed(self._process_fold)(
#    1266             fold_idx,
#    (...)   1269             for fold_idx, (train_index, test_index) in enumerate(kf.split(self.Y))
#    1270     )
#
# File ~/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/joblib/parallel.py:1784, in Parallel._retrieve(self)
#    1778 while self._wait_retrieval():
#    1779     # If the callback thread of a worker has signaled that its task
#    1780     # triggered an exception, or if the retrieval loop has raised an
#    1781     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1782     # worker traceback.
#    1783     if self._aborting:
# -> 1784         self._raise_error_fast()
#    1785         break
#    1787     nb_jobs = len(self._jobs)
#
# File ~/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/joblib/parallel.py:1859, in Parallel._raise_error_fast(self)
#    1855 # If this error job exists, immediately raise the error by
#    1856 # calling get_result. This job might not exists if abort has been
#    1857 # called directly or if the generator is gc'ed.
#    1858 if error_job is not None:
# -> 1859     error_job.get_result(self.timeout)
#
# File ~/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/joblib/parallel.py:758, in BatchCompletionCallBack.get_result(self, timeout)
#     752 backend = self.parallel._backend
#     754 if backend.supports_retrieve_callback:
#     755     # We assume that the result has already been retrieved by the
#     756     # callback thread, and is stored internally. It's just waiting to
#     757     # be returned.
# --> 758     return self._return_or_raise()
#     760 # For other backends, the main thread needs to run the retrieval step.
#     761 try:
#
# File ~/micromamba/envs/nnpiv_env/lib/python3.11/site-packages/joblib/parallel.py:773, in BatchCompletionCallBack._return_or_raise(self)
#     771 try:
#     772     if self.status == TASK_ERROR:
# --> 773         raise self._result
#     774     return self._result
#     775 finally:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required by Nystroem.

# %%
G.shape
# Out:
# (1000, 1)
